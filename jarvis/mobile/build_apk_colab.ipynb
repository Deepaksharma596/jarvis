# %% [markdown]
# # 📱 Build JARVIS Mobile APK on Google Colab (Free 1-Click Online Build)
#
# Run this notebook in Google Colab to build `JARVIS_Mobile-1.0.0-debug.apk` directly online without installing Linux on Windows!

# %%
# 1. Install Linux Buildozer Dependencies
# !sudo apt-get update
# !sudo apt-get install -y build-essential ccache git libffi-dev libssl-dev python3-dev zip unzip zlib1g-dev openjdk-17-jdk
# !pip install --upgrade buildozer cython

# %%
# 2. Clone or Upload JARVIS Code
# Upload your jarvis folder or buildozer.spec
# %cd /content
# !buildozer init

# %%
# 3. Compile Android APK
# !buildozer android debug

# %%
# 4. Download Generated APK
from google.colab import files
files.download('/content/bin/JARVIS_Mobile-1.0.0-debug.apk')
